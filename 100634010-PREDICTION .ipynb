# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#read product_csv file as dataframe called product
products = pd.read_csv("Products_Filtered.csv")

# %%
#Check the head of product,its info and describe() methods

# %%
Products=products.dropna()

# %%
Products.describe()
# Out:
#        ProductKey  ProductSubcategoryKey  StandardCost  SafetyStockLevel  \
# count  104.000000             104.000000    104.000000        104.000000
# mean   486.615385               7.384615    640.450834        269.230769
# std    109.503585               6.355653    453.981206        198.575961
# min    240.000000               1.000000     17.977600        100.000000
# 25%    389.500000               2.000000    294.579700        100.000000
# 50%    508.500000               3.000000    461.444800        100.000000
# 75%    577.250000              14.000000    868.634200        500.000000
# max    606.000000              16.000000   1554.947900        500.000000
#
#        ReorderPoint    ListPrice      Weight  DaysToManufacture  DealerPrice
# count    104.000000   104.000000  104.000000         104.000000   104.000000
# mean     201.923077  1059.615096   25.738365           2.740385   635.769058
# std      148.931971   740.278436   42.043206           1.481243   444.167062
# ...

# %%
Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 239 to 605
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ProductKey             104 non-null    int64
#  1   ProductAlternateKey    104 non-null    object
#  2   ProductSubcategoryKey  104 non-null    int64
#  3   EnglishProductName     104 non-null    object
#  4   FrenchProductName      104 non-null    object
#  5   StandardCost           104 non-null    float64
#  6   FinishedGoodsFlag      104 non-null    bool
#  7   SafetyStockLevel       104 non-null    int64
#  8   ReorderPoint           104 non-null    int64
#  9   ListPrice              104 non-null    float64
#  10  Weight                 104 non-null    float64
#  11  DaysToManufacture      104 non-null    int64
#  12  ProductLine            104 non-null    object
#  13  DealerPrice            104 non-null    float64
# ...

# %%
#convert integers in the dataset to float
Products['FinishedGoodsFlag']=Products['FinishedGoodsFlag'].astype(float)
Products['DaysToManufacture']=Products['DaysToManufacture'].astype(float)
Products['ReorderPoint']=Products['ReorderPoint'].astype(float)
Products['SafetyStockLevel']=Products['SafetyStockLevel'].astype(float)
Products['ProductSubcategoryKey']=Products['ProductSubcategoryKey'].astype(float)
# Out:
# C:\Users\44787\AppData\Local\Temp\ipykernel_12300\60668184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products['FinishedGoodsFlag']=Products['FinishedGoodsFlag'].astype(float)
# C:\Users\44787\AppData\Local\Temp\ipykernel_12300\60668184.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Products['DaysToManufacture']=Products['DaysToManufacture'].astype(float)
# C:\Users\44787\AppData\Local\Temp\ipykernel_12300\60668184.py:4: SettingWithCopyWarning:
# ...

# %%
# Exploratory data analysis: By using seaborn to create a joint plot to compare Dealers price and List price

# %%
sns.set_palette("GnBu_d")
sns.set_style('whitegrid')

# %%
pwd
# Out:
# 'C:\\Users\\44787\\OneDrive - University of Derby\\Big Data\\Assigment\\Res'

# %%
# the higher the price of the Dealer,the higher the list price.
sns.jointplot(x='DealerPrice',y='ListPrice',data=Products)

# %%
# Exploratory data analysis: By using seaborn to create a joint plot to compare Dealers price and Standard Cost

# %%
sns.jointplot(x='DealerPrice',y='StandardCost',data=Products)

# %%
#Use jointplot to create a 2D hex bin plot comparing DealerPrice and ReorderPoint.

# %%
sns.jointplot(x='DealerPrice',y='ReorderPoint',kind='hex',data=Products)

# %%
 #Use pairplot to recreate the plot below top explore the types of relationships across the entire data set.

# %%
sns.pairplot(Products)

# %%
#Create a linear model plot (using seaborn's lmplot) of DealersPrice vs. StandardCost.

# %%
sns.lmplot(x='DealerPrice',y='StandardCost',data=Products)

# %%
#Set a variable X equal to the numerical features of the Products and a variable y equal to the ListPrice column. **

# %%
y = Products['ListPrice']

# %%
print(y)
# Out:
# 239    1431.50
# 242    1431.50
# 245    1431.50
# 248    1431.50
# 251    1431.50
#         ...
# 598     539.99
# 599     539.99
# 603     539.99
# 604     539.99
# 605     539.99
# Name: ListPrice, Length: 104, dtype: float64

# %%
X = Products[['DealerPrice', 'StandardCost','ReorderPoint']]

# %%
print(X)
# Out:
#      DealerPrice  StandardCost  ReorderPoint
# 239      858.900      868.6342         375.0
# 242      858.900      868.6342         375.0
# 245      858.900      868.6342         375.0
# 248      858.900      868.6342         375.0
# 251      858.900      868.6342         375.0
# ..           ...           ...           ...
# 598      323.994      294.5797          75.0
# 599      323.994      294.5797          75.0
# 603      323.994      343.6496          75.0
# 604      323.994      343.6496          75.0
# 605      323.994      343.6496          75.0
#
# [104 rows x 3 columns]

# %%
#Use model_selection.train_test_split from sklearn to split the data into training and testing sets. **

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#Training the Model

# Import LinearRegression from sklearn.linear_model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
#Train/fit lm on the training data.

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Print out the coefficients of the model

# %%
# The coefficients
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [1.66666667e+00 8.69708881e-16 4.32227505e-16]

# %%
#Predicting Test Data
#after fitting the model,the next thing to do is to evaluate its performance by predicting off the test values!

# Using lm.predict() to predict off the X_test set of the data.**

# %%
predictions = lm.predict( X_test)

# %%
#Create a scatterplot of the real test values versus the predicted values.

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
#Evaluating the Model
#evaluate the model performance by calculating the residual sum of squares and the explained variance score (R^2).

#Calculate the Mean Absolute Error, Mean Squared Error, and the Root Mean Squared Error.

# %%
# calculate these metrics!
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 9.126033262418787e-14
# MSE: 1.835994870811383e-26
# RMSE: 1.3549888821726113e-13

# %%
sns.distplot((y_test-predictions),bins=50);
# Out:
# C:\Users\44787\anaconda3\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Coefficient
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#                Coeffecient
# DealerPrice   1.666667e+00
# StandardCost  8.697089e-16
# ReorderPoint  4.322275e-16
